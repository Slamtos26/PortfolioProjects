# %% [markdown]
# <a href="https://colab.research.google.com/github/Slamtos26/PortfolioProjects/blob/main/MSC_PROJECT_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification using Convolutional Neural Networks

# %% [markdown]
# In this exercise, we demonstrate how to classify remotely sensed images into 21 different land use classes, assigining a single label for each image. The dataset used for this exercise is the [UC Merced Land Use dataset](http://weegee.vision.ucmerced.edu/datasets/landuse.html)&mdash;containing 100 images of size 256$\times$256 pixels for each of the 21 classes [1]. The image patches were manually extracted from the USGS National Map Urban Area Imagery collection of images for various urban areas of the United States. The images have a spatial resolution of one foot.
#
# The code in this notebook can be run by clicking the cell containing the code block and pressing SHIFT+ENTER.

# %% [markdown]
# ### Importing Libraries
#
# We first import necessary libraries and functions that we are gonna use for the exercise.

# %%
import tensorflow as tf
import tensorflow.keras.models as models
import tensorflow.keras.layers as layers
import tensorflow.keras.optimizers as optimizers
import tensorflow.keras.utils as kutils
import sklearn.ensemble
import sklearn.metrics
import skimage.feature
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pickle
import os
from tqdm import tqdm

# %%
from tensorflow.keras.utils import to_categorical
y_val_one_hot = to_categorical(y_val, num_classes=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-26b68bfe0f00> in <cell line: 2>()
#       1 from tensorflow.keras.utils import to_categorical
# ----> 2 y_val_one_hot = to_categorical(y_val, num_classes=4)
#
# NameError: name 'y_val' is not defined

# %% [markdown]
# ### Reading the images
#
# We then read the images from the data directory into numpy arrays. For each class, we take `VALIDATION_COUNT` samples for validation and the rest&mdash;for training.

# %%
VALIDATION_COUNT = 30

# %% [markdown]
# First, we initialize the random number generator with a predefined seed to make our results reproducible.

# %%
SEED = 42
np.random.seed(SEED)

# %%
from google.colab import drive
drive.mount("/content/gdrive")
ROOT_DIR = os.path.join("gdrive", "My Drive", "MSC2", "Sample_project")
# Out:
# Mounted at /content/gdrive

# %%
IMAGES_DIR = os.path.join(ROOT_DIR, "dataset", "images")
CLASS_NAMES = sorted(os.listdir(IMAGES_DIR))
CLASSES_COUNT = len(CLASS_NAMES)
HEIGHT, WIDTH, DEPTH = 256, 256, 3

# %%
x_train, y_train, x_val, y_val = [], [], [], []

for label, class_name in enumerate(CLASS_NAMES): # loop over all classes
    class_dir = os.path.join(IMAGES_DIR, class_name)
    filenames = os.listdir(class_dir)
    np.random.shuffle(filenames)

    images, labels = [], []
    for filename in filenames: # loop over all images of class
        image_path = os.path.join(class_dir, filename)
        image = cv2.imread(image_path).astype(np.float32)[:, :, ::-1] # read image
        image /= 255 # rescale brightness to [0; 1]

        # some images in dataset have slightly different sizes, resize them
        if image.shape[0] != HEIGHT or image.shape[1] != WIDTH:
            image = cv2.resize(image, (HEIGHT, WIDTH))

        images.append(image)
        labels.append([label])

    x_train.extend(images[VALIDATION_COUNT:])
    y_train.extend(labels[VALIDATION_COUNT:])
    x_val.extend(images[:VALIDATION_COUNT])
    y_val.extend(labels[:VALIDATION_COUNT])

x_train = np.array(x_train)
y_train = np.array(y_train)
x_val = np.array(x_val)
y_val = np.array(y_val)

# change label to one-hot: [0] -> [1 0 0 0], [1] -> [0 1 0 0], so on
y_train = kutils.to_categorical(y_train, CLASSES_COUNT)
y_val = kutils.to_categorical(y_val, CLASSES_COUNT)

# %% [markdown]
# <h3>Question 1:</h3>
# <br>
# How many dimensions do the input and target arrays have? How does categorical encoding change the dimensions?

# %% [markdown]
# <h3>Question 2:</h3>
# <br>
# What are min and max values of the input arrays? How is it different from the way they are stored on the disk?

# %% [markdown]
# ### Model definition
#
# Training deep networks takes a lot of time even especially when using the CPU for all the computations. We therefore train a small sample network for a small number of epochs in this exercise. If you have more time for the exercise, you can play with the training hyperparameters, e.g. training the sample network for longer epochs.
#
# There are two common ways to define your model in `tensorflow.keras`&mdash;sequential and functional. If you use sequential interface, you define your model as a stack of layers.

# %%
def get_model(input_shape, classes_count):
    model = models.Sequential()
    model.add(layers.Conv2D(32, kernel_size=3, activation="relu", input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=2))
    model.add(layers.Conv2D(32, kernel_size=3, activation="relu"))
    model.add(layers.MaxPooling2D(pool_size=2))
    model.add(layers.Dropout(0.25))
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation="relu"))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(classes_count, activation="softmax"))
    return model

# %%
model = get_model((HEIGHT, WIDTH, DEPTH), CLASSES_COUNT)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 62, 62, 32)        0
#
#  flatten (Flatten)           (None, 123008)            0
#
#  dense (Dense)               (None, 128)               15745152
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 15755812 (60.10 MB)
# Trainable params: 15755812 (60.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# The second interface is functional, it allows defining a model in the same way you write mathematical expressions in programming languages, therefore, you do not define a stack of layers but a computational graph that represents the model. The functional interface is more flexible making it simple to define models with several inputs and outputs or several parallel branches, etc.

# %%
def get_model(input_shape, classes_count):
    input = layers.Input(input_shape)
    conv1 = layers.Conv2D(32, kernel_size=3, activation="relu")(input)
    pool1 = layers.MaxPooling2D(pool_size=2)(conv1)
    conv2 = layers.Conv2D(32, kernel_size=3, activation="relu")(pool1)
    pool2 = layers.MaxPooling2D(pool_size=2)(conv2)
    dropout1 = layers.Dropout(0.25)(pool2)
    flatten = layers.Flatten()(dropout1)
    dense1 = layers.Dense(128, activation="relu")(flatten)
    dropout2 = layers.Dropout(0.5)(dense1)
    output = layers.Dense(classes_count, activation="softmax")(dropout2)

    model = models.Model(inputs=input, outputs=output)
    return model

# %%
model = get_model((HEIGHT, WIDTH, DEPTH), CLASSES_COUNT)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_2 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 62, 62, 32)        0
#
#  flatten_1 (Flatten)         (None, 123008)            0
#
#  dense_2 (Dense)             (None, 128)               15745152
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 15755812 (60.10 MB)
# Trainable params: 15755812 (60.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# <h3>Question 3:</h3>
# <br>
# How many layers with trainable parameters does the sample network have? How are two models defined in two different ways different?

# %% [markdown]
# ### Training the network
#
# Once everything is prepared, model training can be initiated by calling two methods&mdash;`compile` and `fit`.

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=optimizers.SGD(learning_rate=1e-2),
    metrics=["accuracy"]
)

# %%
EPOCHS = 40
BATCH_SIZE = 32

history = model.fit(
    x_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/40
# 9/9 [==============================] - 27s 3s/step - loss: 1.4256 - accuracy: 0.2714 - val_loss: 1.3647 - val_accuracy: 0.2500
# Epoch 2/40
# 9/9 [==============================] - 28s 3s/step - loss: 1.3732 - accuracy: 0.2429 - val_loss: 1.3619 - val_accuracy: 0.2500
# Epoch 3/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.3421 - accuracy: 0.2714 - val_loss: 1.3436 - val_accuracy: 0.2500
# Epoch 4/40
# 9/9 [==============================] - 24s 3s/step - loss: 1.3299 - accuracy: 0.3286 - val_loss: 1.3169 - val_accuracy: 0.3917
# Epoch 5/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.3161 - accuracy: 0.3536 - val_loss: 1.2875 - val_accuracy: 0.3583
# Epoch 6/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.2770 - accuracy: 0.4357 - val_loss: 1.2489 - val_accuracy: 0.3833
# Epoch 7/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.2322 - accuracy: 0.4643 - val_loss: 1.1753 - val_accuracy: 0.5333
# Epoch 8/40
# 9/9 [==============================] - 24s 3s/step - loss: 1.1767 - accuracy: 0.5071 - val_loss: 1.0687 - val_accuracy: 0.6083
# Epoch 9/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.2030 - accuracy: 0.4750 - val_loss: 1.1154 - val_accuracy: 0.6667
# Epoch 10/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.0720 - accuracy: 0.5464 - val_loss: 1.1106 - val_accuracy: 0.4750
# Epoch 11/40
# 9/9 [==============================] - 27s 3s/step - loss: 1.0925 - accuracy: 0.5214 - val_loss: 1.0521 - val_accuracy: 0.5583
# Epoch 12/40
# 9/9 [==============================] - 24s 3s/step - loss: 1.0110 - accuracy: 0.5893 - val_loss: 1.0035 - val_accuracy: 0.5333
# Epoch 13/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.9939 - accuracy: 0.5357 - val_loss: 0.9680 - val_accuracy: 0.5250
# Epoch 14/40
# 9/9 [==============================] - 26s 3s/step - loss: 1.2684 - accuracy: 0.4929 - val_loss: 1.1534 - val_accuracy: 0.4583
# Epoch 15/40
# 9/9 [==============================] - 27s 3s/step - loss: 1.0790 - accuracy: 0.5179 - val_loss: 1.0106 - val_accuracy: 0.7083
# Epoch 16/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.9699 - accuracy: 0.6036 - val_loss: 0.9353 - val_accuracy: 0.7000
# Epoch 17/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.9540 - accuracy: 0.6250 - val_loss: 0.9672 - val_accuracy: 0.6000
# Epoch 18/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.9287 - accuracy: 0.5929 - val_loss: 0.9973 - val_accuracy: 0.5417
# Epoch 19/40
# 9/9 [==============================] - 27s 3s/step - loss: 0.8315 - accuracy: 0.6821 - val_loss: 0.8895 - val_accuracy: 0.5667
# Epoch 20/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.8726 - accuracy: 0.6321 - val_loss: 0.8361 - val_accuracy: 0.6667
# Epoch 21/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.8070 - accuracy: 0.6750 - val_loss: 0.9473 - val_accuracy: 0.5500
# Epoch 22/40
# 9/9 [==============================] - 28s 3s/step - loss: 0.7792 - accuracy: 0.6893 - val_loss: 0.7747 - val_accuracy: 0.6417
# Epoch 23/40
# 9/9 [==============================] - 27s 3s/step - loss: 0.6940 - accuracy: 0.7536 - val_loss: 0.9191 - val_accuracy: 0.5583
# Epoch 24/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.7818 - accuracy: 0.6714 - val_loss: 1.1191 - val_accuracy: 0.5417
# Epoch 25/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.7017 - accuracy: 0.7321 - val_loss: 0.8126 - val_accuracy: 0.6500
# Epoch 26/40
# 9/9 [==============================] - 28s 3s/step - loss: 0.6553 - accuracy: 0.7607 - val_loss: 0.9381 - val_accuracy: 0.6083
# Epoch 27/40
# 9/9 [==============================] - 28s 3s/step - loss: 0.8025 - accuracy: 0.7036 - val_loss: 0.7381 - val_accuracy: 0.7583
# Epoch 28/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.6259 - accuracy: 0.8000 - val_loss: 0.7439 - val_accuracy: 0.6667
# Epoch 29/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.6355 - accuracy: 0.7607 - val_loss: 0.7039 - val_accuracy: 0.6833
# Epoch 30/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.6015 - accuracy: 0.7714 - val_loss: 0.6732 - val_accuracy: 0.7167
# Epoch 31/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.5365 - accuracy: 0.8250 - val_loss: 0.6703 - val_accuracy: 0.7667
# Epoch 32/40
# 9/9 [==============================] - 27s 3s/step - loss: 0.7038 - accuracy: 0.7214 - val_loss: 0.7064 - val_accuracy: 0.7250
# Epoch 33/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.5808 - accuracy: 0.8107 - val_loss: 0.6850 - val_accuracy: 0.7583
# Epoch 34/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.4634 - accuracy: 0.8571 - val_loss: 0.6555 - val_accuracy: 0.7667
# Epoch 35/40
# 9/9 [==============================] - 28s 3s/step - loss: 0.5187 - accuracy: 0.8036 - val_loss: 0.7700 - val_accuracy: 0.6500
# Epoch 36/40
# 9/9 [==============================] - 27s 3s/step - loss: 0.4492 - accuracy: 0.8500 - val_loss: 0.6602 - val_accuracy: 0.7333
# Epoch 37/40
# 9/9 [==============================] - 24s 3s/step - loss: 0.4358 - accuracy: 0.8536 - val_loss: 0.6353 - val_accuracy: 0.7750
# Epoch 38/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.4270 - accuracy: 0.8643 - val_loss: 0.6189 - val_accuracy: 0.7500
# Epoch 39/40
# 9/9 [==============================] - 26s 3s/step - loss: 0.5261 - accuracy: 0.8143 - val_loss: 0.6460 - val_accuracy: 0.7083
# Epoch 40/40
# 9/9 [==============================] - 27s 3s/step - loss: 0.3933 - accuracy: 0.8893 - val_loss: 0.6523 - val_accuracy: 0.7083

# %%
# plot model training history
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].set_title("Sample net training curve loss")
axs[0].plot(history.history["loss"], label="train")
axs[0].plot(history.history["val_loss"], label="val")
axs[0].legend()
axs[0].set_ylabel("loss")
axs[0].set_xlabel("epoch")

axs[1].set_title("Sample net training curve error rate")
axs[1].plot([1 - _ for _ in history.history["accuracy"]], label="train")
axs[1].plot([1 - _ for _ in history.history["val_accuracy"]], label="val")
axs[1].legend()
axs[1].set_ylabel("error rate")
axs[1].set_xlabel("epoch")

plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(x_val, y_val)
print(f"\nTesting accuracy of the sample network: {100 * accuracy:.2f}%")
# Out:
# 4/4 [==============================] - 2s 578ms/step - loss: 0.6523 - accuracy: 0.7083
#
# Testing accuracy of the sample network: 70.83%

# %% [markdown]
# <h3>Question 4:</h3>
# <br>
# Comparing the curves for training and validation, what conclusions can be made?

# %% [markdown]
# ### Training baseline classifier
# We train a random forest classifier on raw image and local binary patterns [2] features.

# %%
# flatten training set into row vectors
# and restore label encoding
y_train_rf = np.argmax(y_train, axis=-1)
y_val_rf = np.argmax(y_val, axis=-1)
x_train_flatten = x_train.reshape(x_train.shape[0], -1)
x_val_flatten = x_val.reshape(x_val.shape[0], -1)

# train random forest classifier
classifier = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    random_state=0
)
classifier.fit(x_train_flatten, y_train_rf)

# predict test set and print overall accuracy
predictions_rf = classifier.predict(x_val_flatten)
accuracy_rf = sklearn.metrics.accuracy_score(predictions_rf, y_val_rf)
print(f"\nTesting accuracy of RF on flatten images: {100 * accuracy_rf:.2f}%")
# Out:
# Testing accuracy of RF on flatten images: 74.17%

# %%
def extract_lbp(img_array, n_points, radius):
    """Function for extracting local binary patterns codes.
    The input array, imgarray, is a 4D image volume with
    samples along the first axis. LBP code histograms are
    computed over the whole image sample extent and for all
    bands of the image.
    """
    n_samples, n_rows, n_cols, n_bands = img_array.shape
    n_features = (n_points + 2) * n_bands
    n_features_per_band = n_features // n_bands
    img_array_lbp = np.zeros((img_array.shape[0], n_features), dtype=np.float32)

    with tqdm(total=n_samples) as pbar:
        for sample_idx in range(n_samples):
            img = img_array[sample_idx]
            img_codes = np.empty((n_rows, n_cols, n_bands), dtype="int32")
            for i in range(n_bands):
                img_codes[:, :, i] = skimage.feature.local_binary_pattern(
                    img[:, :, i], n_points, radius, method="uniform"
                )
            img_codecounts = np.zeros((n_features,), dtype=np.int32)
            for i in range(n_bands):
                img_codecounts[i*(n_features_per_band):(i+1)*(n_features_per_band)] = \
                    np.histogram(img_codes[:, :, i], bins=n_features_per_band)[0]
            img_array_lbp[sample_idx] = img_codecounts

            pbar.update(1)

    return img_array_lbp

# %%
# extract LBP features
N_POINTS = 12 # set number of points for LBP
RADIUS = 16 # set radius for LBP

x_train_lbp = extract_lbp(x_train, N_POINTS, RADIUS)
x_val_lbp = extract_lbp(x_val, N_POINTS, RADIUS)

# train random forest classifier
classifier = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    random_state=0
)
classifier.fit(x_train_lbp, y_train_rf)

# predict test set and print overall accuracy
predictions_rf = classifier.predict(x_val_lbp)
accuracy_rf = sklearn.metrics.accuracy_score(predictions_rf, y_val_rf)
print(f"\nTesting accuracy of RF on flatten images: {100 * accuracy_rf:.2f}%")
# Out:
# 100%|██████████| 280/280 [00:17<00:00, 15.76it/s]
# 100%|██████████| 120/120 [00:08<00:00, 13.86it/s]
# Testing accuracy of RF on flatten images: 79.17%

# %% [markdown]
# ### Evaluating the accuracy of pre-trained networks
#
# Finally, we evaluate the accuracy of two pre-trained deep networks based on VGG16 [3] and Inceptionv3 architecture [4]. The models are trained on the same training set with data augmentation of two flips and three 90 degree rotations applied to each of the patch and using the Adam optimizer [5].
#
# ##### VGG16

# %%
VGG16_PATH = os.path.join(ROOT_DIR, "pretrained", "pretrained_VGG16.hdf5")
model = models.load_model(VGG16_PATH)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense

from tensorflow.keras.models import load_model

# After importing, you can use load_model to load your saved model
model = load_model(VGG16_PATH)



# Load the pre-trained VGG16 model
#model = load_model.(VGG16_PATH)
#loss, accuracy = new_model.evaluate(x_val, y_val)
# Assume that 'model' is of the 'Functional' type.

# Get the output of the last but one layer, which is before the final Dense layer with 21 units
x = model.layers[-2].output

# Create a new Dense layer with 4 units (for 4 classes) that will be added on top of the current model
new_output = Dense(4, activation='softmax')(x)

# Create the new model
new_model = Model(inputs=model.input, outputs=new_output)

# Compile the new model
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Check the summary to verify the new structure
new_model.summary()
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  max_pooling2d_1 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 4096)              2101248
#
#  batch_normalization_1 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  activation_1 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_2 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  activation_2 (Activation)   (None, 4096)              0
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 33646404 (128.35 MB)
# Trainable params: 33630020 (128.29 MB)
# Non-trainable params: 16384 (64.00 KB)
# _________________________________________________________________

# %%
TRAIN_HISTORY_PATH = os.path.join(ROOT_DIR, "pretrained", "VGG16_train_history")
with open(TRAIN_HISTORY_PATH, "rb") as history_file:
    history = pickle.load(history_file)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].set_title("Sample net training curve loss")
axs[0].plot(history["loss"], label="train")
axs[0].plot(history["val_loss"], label="val")
axs[0].legend()
axs[0].set_ylabel("loss")
axs[0].set_xlabel("epoch")

axs[1].set_title("Sample net training curve error rate")
axs[1].plot([1 - _ for _ in history["acc"]], label="train")
axs[1].plot([1 - _ for _ in history["val_acc"]], label="val")
axs[1].legend()
axs[1].set_ylabel("error rate")
axs[1].set_xlabel("epoch")

plt.tight_layout()
plt.show()

# %%
loss, accuracy = new_model.evaluate(x_val, y_val)
print(f"\nTesting accuracy of the sample network: {100 * accuracy:.2f}%")
# Out:
# 4/4 [==============================] - 100s 24s/step - loss: 1.6537 - accuracy: 0.3083
#
# Testing accuracy of the sample network: 30.83%

# %% [markdown]
# ##### InceptionV3

# %%
INCEPTION_PATH = os.path.join(ROOT_DIR, "pretrained", "pretrained_Inception_v3.hdf5")
model = models.load_model(INCEPTION_PATH)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_400 (Conv2D)         (None, 127, 127, 32)         864       ['input_7[0][0]']
#
#  batch_normalization_400 (B  (None, 127, 127, 32)         96        ['conv2d_400[0][0]']
#  atchNormalization)
#
#  activation_399 (Activation  (None, 127, 127, 32)         0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  conv2d_401 (Conv2D)         (None, 125, 125, 32)         9216      ['activation_399[0][0]']
#
#  batch_normalization_401 (B  (None, 125, 125, 32)         96        ['conv2d_401[0][0]']
#  atchNormalization)
#
#  activation_400 (Activation  (None, 125, 125, 32)         0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  conv2d_402 (Conv2D)         (None, 125, 125, 64)         18432     ['activation_400[0][0]']
#
#  batch_normalization_402 (B  (None, 125, 125, 64)         192       ['conv2d_402[0][0]']
#  atchNormalization)
#
#  activation_401 (Activation  (None, 125, 125, 64)         0         ['batch_normalization_402[0][0
#  )                                                                  ]']
#
#  max_pooling2d_19 (MaxPooli  (None, 62, 62, 64)           0         ['activation_401[0][0]']
#  ng2D)
#
#  conv2d_403 (Conv2D)         (None, 62, 62, 80)           5120      ['max_pooling2d_19[0][0]']
#
#  batch_normalization_403 (B  (None, 62, 62, 80)           240       ['conv2d_403[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 62, 62, 80)           0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_404 (Conv2D)         (None, 60, 60, 192)          138240    ['activation_402[0][0]']
#
#  batch_normalization_404 (B  (None, 60, 60, 192)          576       ['conv2d_404[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 60, 60, 192)          0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  max_pooling2d_20 (MaxPooli  (None, 29, 29, 192)          0         ['activation_403[0][0]']
#  ng2D)
#
#  conv2d_408 (Conv2D)         (None, 29, 29, 64)           12288     ['max_pooling2d_20[0][0]']
#
#  batch_normalization_408 (B  (None, 29, 29, 64)           192       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  conv2d_406 (Conv2D)         (None, 29, 29, 48)           9216      ['max_pooling2d_20[0][0]']
#
#  conv2d_409 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_407[0][0]']
#
#  batch_normalization_406 (B  (None, 29, 29, 48)           144       ['conv2d_406[0][0]']
#  atchNormalization)
#
#  batch_normalization_409 (B  (None, 29, 29, 96)           288       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  activation_405 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  activation_408 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  average_pooling2d_43 (Aver  (None, 29, 29, 192)          0         ['max_pooling2d_20[0][0]']
#  agePooling2D)
#
#  conv2d_405 (Conv2D)         (None, 29, 29, 64)           12288     ['max_pooling2d_20[0][0]']
#
#  conv2d_407 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_405[0][0]']
#
#  conv2d_410 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_408[0][0]']
#
#  conv2d_411 (Conv2D)         (None, 29, 29, 32)           6144      ['average_pooling2d_43[0][0]']
#
#  batch_normalization_405 (B  (None, 29, 29, 64)           192       ['conv2d_405[0][0]']
#  atchNormalization)
#
#  batch_normalization_407 (B  (None, 29, 29, 64)           192       ['conv2d_407[0][0]']
#  atchNormalization)
#
#  batch_normalization_410 (B  (None, 29, 29, 96)           288       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  batch_normalization_411 (B  (None, 29, 29, 32)           96        ['conv2d_411[0][0]']
#  atchNormalization)
#
#  activation_404 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_405[0][0
#  )                                                                  ]']
#
#  activation_406 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  activation_409 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  activation_410 (Activation  (None, 29, 29, 32)           0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 29, 29, 256)          0         ['activation_404[0][0]',
#                                                                      'activation_406[0][0]',
#                                                                      'activation_409[0][0]',
#                                                                      'activation_410[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 29, 29, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_415 (B  (None, 29, 29, 64)           192       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_414 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  conv2d_413 (Conv2D)         (None, 29, 29, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_416 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_414[0][0]']
#
#  batch_normalization_413 (B  (None, 29, 29, 48)           144       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  batch_normalization_416 (B  (None, 29, 29, 96)           288       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  activation_412 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  activation_415 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  average_pooling2d_44 (Aver  (None, 29, 29, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_412 (Conv2D)         (None, 29, 29, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_414 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_412[0][0]']
#
#  conv2d_417 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_415[0][0]']
#
#  conv2d_418 (Conv2D)         (None, 29, 29, 64)           16384     ['average_pooling2d_44[0][0]']
#
#  batch_normalization_412 (B  (None, 29, 29, 64)           192       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  batch_normalization_414 (B  (None, 29, 29, 64)           192       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  batch_normalization_417 (B  (None, 29, 29, 96)           288       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  batch_normalization_418 (B  (None, 29, 29, 64)           192       ['conv2d_418[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  activation_413 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  activation_416 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  activation_417 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 29, 29, 288)          0         ['activation_411[0][0]',
#                                                                      'activation_413[0][0]',
#                                                                      'activation_416[0][0]',
#                                                                      'activation_417[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_422 (B  (None, 29, 29, 64)           192       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_420 (Conv2D)         (None, 29, 29, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_421[0][0]']
#
#  batch_normalization_420 (B  (None, 29, 29, 48)           144       ['conv2d_420[0][0]']
#  atchNormalization)
#
#  batch_normalization_423 (B  (None, 29, 29, 96)           288       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_419 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  activation_422 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  average_pooling2d_45 (Aver  (None, 29, 29, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_419 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_421 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_419[0][0]']
#
#  conv2d_424 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_422[0][0]']
#
#  conv2d_425 (Conv2D)         (None, 29, 29, 64)           18432     ['average_pooling2d_45[0][0]']
#
#  batch_normalization_419 (B  (None, 29, 29, 64)           192       ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_421 (B  (None, 29, 29, 64)           192       ['conv2d_421[0][0]']
#  atchNormalization)
#
#  batch_normalization_424 (B  (None, 29, 29, 96)           288       ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_425 (B  (None, 29, 29, 64)           192       ['conv2d_425[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_420 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  activation_423 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_424 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 29, 29, 288)          0         ['activation_418[0][0]',
#                                                                      'activation_420[0][0]',
#                                                                      'activation_423[0][0]',
#                                                                      'activation_424[0][0]']
#
#  conv2d_427 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_427 (B  (None, 29, 29, 64)           192       ['conv2d_427[0][0]']
#  atchNormalization)
#
#  activation_426 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_427[0][0
#  )                                                                  ]']
#
#  conv2d_428 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_426[0][0]']
#
#  batch_normalization_428 (B  (None, 29, 29, 96)           288       ['conv2d_428[0][0]']
#  atchNormalization)
#
#  activation_427 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_428[0][0
#  )                                                                  ]']
#
#  conv2d_426 (Conv2D)         (None, 14, 14, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_429 (Conv2D)         (None, 14, 14, 96)           82944     ['activation_427[0][0]']
#
#  batch_normalization_426 (B  (None, 14, 14, 384)          1152      ['conv2d_426[0][0]']
#  atchNormalization)
#
#  batch_normalization_429 (B  (None, 14, 14, 96)           288       ['conv2d_429[0][0]']
#  atchNormalization)
#
#  activation_425 (Activation  (None, 14, 14, 384)          0         ['batch_normalization_426[0][0
#  )                                                                  ]']
#
#  activation_428 (Activation  (None, 14, 14, 96)           0         ['batch_normalization_429[0][0
#  )                                                                  ]']
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 14, 14, 768)          0         ['activation_425[0][0]',
#                                                                      'activation_428[0][0]',
#                                                                      'max_pooling2d_21[0][0]']
#
#  conv2d_434 (Conv2D)         (None, 14, 14, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_434 (B  (None, 14, 14, 128)          384       ['conv2d_434[0][0]']
#  atchNormalization)
#
#  activation_433 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_434[0][0
#  )                                                                  ]']
#
#  conv2d_435 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_433[0][0]']
#
#  batch_normalization_435 (B  (None, 14, 14, 128)          384       ['conv2d_435[0][0]']
#  atchNormalization)
#
#  activation_434 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_435[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 14, 14, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_436 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_434[0][0]']
#
#  batch_normalization_431 (B  (None, 14, 14, 128)          384       ['conv2d_431[0][0]']
#  atchNormalization)
#
#  batch_normalization_436 (B  (None, 14, 14, 128)          384       ['conv2d_436[0][0]']
#  atchNormalization)
#
#  activation_430 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_431[0][0
#  )                                                                  ]']
#
#  activation_435 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_436[0][0
#  )                                                                  ]']
#
#  conv2d_432 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_430[0][0]']
#
#  conv2d_437 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_435[0][0]']
#
#  batch_normalization_432 (B  (None, 14, 14, 128)          384       ['conv2d_432[0][0]']
#  atchNormalization)
#
#  batch_normalization_437 (B  (None, 14, 14, 128)          384       ['conv2d_437[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_432[0][0
#  )                                                                  ]']
#
#  activation_436 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_437[0][0
#  )                                                                  ]']
#
#  average_pooling2d_46 (Aver  (None, 14, 14, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_430 (Conv2D)         (None, 14, 14, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_433 (Conv2D)         (None, 14, 14, 192)          172032    ['activation_431[0][0]']
#
#  conv2d_438 (Conv2D)         (None, 14, 14, 192)          172032    ['activation_436[0][0]']
#
#  conv2d_439 (Conv2D)         (None, 14, 14, 192)          147456    ['average_pooling2d_46[0][0]']
#
#  batch_normalization_430 (B  (None, 14, 14, 192)          576       ['conv2d_430[0][0]']
#  atchNormalization)
#
#  batch_normalization_433 (B  (None, 14, 14, 192)          576       ['conv2d_433[0][0]']
#  atchNormalization)
#
#  batch_normalization_438 (B  (None, 14, 14, 192)          576       ['conv2d_438[0][0]']
#  atchNormalization)
#
#  batch_normalization_439 (B  (None, 14, 14, 192)          576       ['conv2d_439[0][0]']
#  atchNormalization)
#
#  activation_429 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  activation_432 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_433[0][0
#  )                                                                  ]']
#
#  activation_437 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_438[0][0
#  )                                                                  ]']
#
#  activation_438 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_439[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 14, 14, 768)          0         ['activation_429[0][0]',
#                                                                      'activation_432[0][0]',
#                                                                      'activation_437[0][0]',
#                                                                      'activation_438[0][0]']
#
#  conv2d_444 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_444 (B  (None, 14, 14, 160)          480       ['conv2d_444[0][0]']
#  atchNormalization)
#
#  activation_443 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_444[0][0
#  )                                                                  ]']
#
#  conv2d_445 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_443[0][0]']
#
#  batch_normalization_445 (B  (None, 14, 14, 160)          480       ['conv2d_445[0][0]']
#  atchNormalization)
#
#  activation_444 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_445[0][0
#  )                                                                  ]']
#
#  conv2d_441 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_446 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_444[0][0]']
#
#  batch_normalization_441 (B  (None, 14, 14, 160)          480       ['conv2d_441[0][0]']
#  atchNormalization)
#
#  batch_normalization_446 (B  (None, 14, 14, 160)          480       ['conv2d_446[0][0]']
#  atchNormalization)
#
#  activation_440 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_441[0][0
#  )                                                                  ]']
#
#  activation_445 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_446[0][0
#  )                                                                  ]']
#
#  conv2d_442 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_440[0][0]']
#
#  conv2d_447 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_445[0][0]']
#
#  batch_normalization_442 (B  (None, 14, 14, 160)          480       ['conv2d_442[0][0]']
#  atchNormalization)
#
#  batch_normalization_447 (B  (None, 14, 14, 160)          480       ['conv2d_447[0][0]']
#  atchNormalization)
#
#  activation_441 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_442[0][0
#  )                                                                  ]']
#
#  activation_446 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_447[0][0
#  )                                                                  ]']
#
#  average_pooling2d_47 (Aver  (None, 14, 14, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_440 (Conv2D)         (None, 14, 14, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_443 (Conv2D)         (None, 14, 14, 192)          215040    ['activation_441[0][0]']
#
#  conv2d_448 (Conv2D)         (None, 14, 14, 192)          215040    ['activation_446[0][0]']
#
#  conv2d_449 (Conv2D)         (None, 14, 14, 192)          147456    ['average_pooling2d_47[0][0]']
#
#  batch_normalization_440 (B  (None, 14, 14, 192)          576       ['conv2d_440[0][0]']
#  atchNormalization)
#
#  batch_normalization_443 (B  (None, 14, 14, 192)          576       ['conv2d_443[0][0]']
#  atchNormalization)
#
#  batch_normalization_448 (B  (None, 14, 14, 192)          576       ['conv2d_448[0][0]']
#  atchNormalization)
#
#  batch_normalization_449 (B  (None, 14, 14, 192)          576       ['conv2d_449[0][0]']
#  atchNormalization)
#
#  activation_439 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_440[0][0
#  )                                                                  ]']
#
#  activation_442 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_443[0][0
#  )                                                                  ]']
#
#  activation_447 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_448[0][0
#  )                                                                  ]']
#
#  activation_448 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_449[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 14, 14, 768)          0         ['activation_439[0][0]',
#                                                                      'activation_442[0][0]',
#                                                                      'activation_447[0][0]',
#                                                                      'activation_448[0][0]']
#
#  conv2d_454 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_454 (B  (None, 14, 14, 160)          480       ['conv2d_454[0][0]']
#  atchNormalization)
#
#  activation_453 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_454[0][0
#  )                                                                  ]']
#
#  conv2d_455 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_453[0][0]']
#
#  batch_normalization_455 (B  (None, 14, 14, 160)          480       ['conv2d_455[0][0]']
#  atchNormalization)
#
#  activation_454 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_455[0][0
#  )                                                                  ]']
#
#  conv2d_451 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_456 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_454[0][0]']
#
#  batch_normalization_451 (B  (None, 14, 14, 160)          480       ['conv2d_451[0][0]']
#  atchNormalization)
#
#  batch_normalization_456 (B  (None, 14, 14, 160)          480       ['conv2d_456[0][0]']
#  atchNormalization)
#
# ...
#
#  conv2d_479 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_476[0][0]']
#
#  conv2d_482 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_480[0][0]']
#
#  conv2d_483 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_480[0][0]']
#
#  average_pooling2d_50 (Aver  (None, 6, 6, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_476 (Conv2D)         (None, 6, 6, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_478 (B  (None, 6, 6, 384)            1152      ['conv2d_478[0][0]']
#  atchNormalization)
#
#  batch_normalization_479 (B  (None, 6, 6, 384)            1152      ['conv2d_479[0][0]']
#  atchNormalization)
#
#  batch_normalization_482 (B  (None, 6, 6, 384)            1152      ['conv2d_482[0][0]']
#  atchNormalization)
#
#  batch_normalization_483 (B  (None, 6, 6, 384)            1152      ['conv2d_483[0][0]']
#  atchNormalization)
#
#  conv2d_484 (Conv2D)         (None, 6, 6, 192)            245760    ['average_pooling2d_50[0][0]']
#
#  batch_normalization_476 (B  (None, 6, 6, 320)            960       ['conv2d_476[0][0]']
#  atchNormalization)
#
#  activation_477 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  activation_478 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  activation_481 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  activation_482 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_483[0][0
#  )                                                                  ]']
#
#  batch_normalization_484 (B  (None, 6, 6, 192)            576       ['conv2d_484[0][0]']
#  atchNormalization)
#
#  activation_475 (Activation  (None, 6, 6, 320)            0         ['batch_normalization_476[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 6, 6, 768)            0         ['activation_477[0][0]',
#                                                                      'activation_478[0][0]']
#
#  concatenate_9 (Concatenate  (None, 6, 6, 768)            0         ['activation_481[0][0]',
#  )                                                                   'activation_482[0][0]']
#
#  activation_483 (Activation  (None, 6, 6, 192)            0         ['batch_normalization_484[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 6, 6, 2048)           0         ['activation_475[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'activation_483[0][0]']
#
#  conv2d_489 (Conv2D)         (None, 6, 6, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_489 (B  (None, 6, 6, 448)            1344      ['conv2d_489[0][0]']
#  atchNormalization)
#
#  activation_488 (Activation  (None, 6, 6, 448)            0         ['batch_normalization_489[0][0
#  )                                                                  ]']
#
#  conv2d_486 (Conv2D)         (None, 6, 6, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_490 (Conv2D)         (None, 6, 6, 384)            1548288   ['activation_488[0][0]']
#
#  batch_normalization_486 (B  (None, 6, 6, 384)            1152      ['conv2d_486[0][0]']
#  atchNormalization)
#
#  batch_normalization_490 (B  (None, 6, 6, 384)            1152      ['conv2d_490[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_486[0][0
#  )                                                                  ]']
#
#  activation_489 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_490[0][0
#  )                                                                  ]']
#
#  conv2d_487 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_485[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_485[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_489[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_489[0][0]']
#
#  average_pooling2d_51 (Aver  (None, 6, 6, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_485 (Conv2D)         (None, 6, 6, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_487 (B  (None, 6, 6, 384)            1152      ['conv2d_487[0][0]']
#  atchNormalization)
#
#  batch_normalization_488 (B  (None, 6, 6, 384)            1152      ['conv2d_488[0][0]']
#  atchNormalization)
#
#  batch_normalization_491 (B  (None, 6, 6, 384)            1152      ['conv2d_491[0][0]']
#  atchNormalization)
#
#  batch_normalization_492 (B  (None, 6, 6, 384)            1152      ['conv2d_492[0][0]']
#  atchNormalization)
#
#  conv2d_493 (Conv2D)         (None, 6, 6, 192)            393216    ['average_pooling2d_51[0][0]']
#
#  batch_normalization_485 (B  (None, 6, 6, 320)            960       ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_486 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_487[0][0
#  )                                                                  ]']
#
#  activation_487 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_488[0][0
#  )                                                                  ]']
#
#  activation_490 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_491[0][0
#  )                                                                  ]']
#
#  activation_491 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_492[0][0
#  )                                                                  ]']
#
#  batch_normalization_493 (B  (None, 6, 6, 192)            576       ['conv2d_493[0][0]']
#  atchNormalization)
#
#  activation_484 (Activation  (None, 6, 6, 320)            0         ['batch_normalization_485[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 6, 6, 768)            0         ['activation_486[0][0]',
#                                                                      'activation_487[0][0]']
#
#  concatenate_10 (Concatenat  (None, 6, 6, 768)            0         ['activation_490[0][0]',
#  e)                                                                  'activation_491[0][0]']
#
#  activation_492 (Activation  (None, 6, 6, 192)            0         ['batch_normalization_493[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 6, 6, 2048)           0         ['activation_484[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_10[0][0]',
#                                                                      'activation_492[0][0]']
#
#  average_pooling2d_52 (Aver  (None, 1, 1, 2048)           0         ['mixed10[0][0]']
#  agePooling2D)
#
#  flatten_5 (Flatten)         (None, 2048)                 0         ['average_pooling2d_52[0][0]']
#
#  dense_9 (Dense)             (None, 2048)                 4196352   ['flatten_5[0][0]']
#
#  dropout_5 (Dropout)         (None, 2048)                 0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 21)                   43029     ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 26042165 (99.34 MB)
# Trainable params: 26007733 (99.21 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
TRAIN_HISTORY_PATH = os.path.join(ROOT_DIR, "pretrained", "Inceptionv3_train_history")
with open(TRAIN_HISTORY_PATH, "rb") as history_file:
    history = pickle.load(history_file)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].set_title("Sample net training curve loss")
axs[0].plot(history["loss"], label="train")
axs[0].plot(history["val_loss"], label="val")
axs[0].legend()
axs[0].set_ylabel("loss")
axs[0].set_xlabel("epoch")

axs[1].set_title("Sample net training curve error rate")
axs[1].plot([1 - _ for _ in history["acc"]], label="train")
axs[1].plot([1 - _ for _ in history["val_acc"]], label="val")
axs[1].legend()
axs[1].set_ylabel("error rate")
axs[1].set_xlabel("epoch")

plt.tight_layout()
plt.show()

# %%
loss, accuracy = new_model.evaluate(x_val, y_val)
print(f"\nTesting accuracy of the sample network: {100 * accuracy:.2f}%")
# Out:
# 4/4 [==============================] - 97s 24s/step - loss: 1.6537 - accuracy: 0.3083
#
# Testing accuracy of the sample network: 30.83%

# %% [markdown]
# <h3>Question 5:</h3>
# <br>
# How do the accuracies of the three networks compare?
# <h3>Question 6:</h3>
# <br>
# What were the necessary changes done to the architecture of the pretrained networks to be able to apply it to this land use image classification task?

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
import numpy as np

# Assuming y_val_rf is the correct variable containing the true labels
y_val_integer = y_val_rf.copy()

# Use new_model to predict, not the old model
y_predicted = new_model.predict(x_val)
y_predicted_integer = np.argmax(y_predicted, axis=-1)

# Ensure CLASS_NAMES matches the number of unique classes in y_val_integer
unique_classes = np.unique(y_val_integer)
CLASS_NAMES = ['Agrilculture', 'buildings', 'forest', 'storagetanks']  # Example placeholder names
CLASS_NAMES = [CLASS_NAMES[i] for i in unique_classes]  # Filter based on unique classes

# Create the figure with the desired size BEFORE plotting the confusion matrix
plt.figure(figsize=(16, 16))

# Plot the confusion matrix
ConfusionMatrixDisplay.from_predictions(
    y_val_integer, y_predicted_integer,
    cmap="Blues",
    display_labels=CLASS_NAMES,
    xticks_rotation="vertical"
)

plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()  # Show the plot
# Out:
# 4/4 [==============================] - 98s 23s/step

# %%
print(np.unique(y_val_integer))
print(np.unique(y_predicted_integer))

# Ensure that the length of CLASS_NAMES matches the number of unique classes
print(f"Number of classes in CLASS_NAMES: {len(CLASS_NAMES)}")
# Out:
# [0 1 2 3]
# [0 1 2 3]
# Number of classes in CLASS_NAMES: 4

# %%
# Plot the confusion matrix only if the number of unique classes is correct
if len(unique_classes) == 4:
    # Create the figure with the desired size BEFORE plotting the confusion matrix
    plt.figure(figsize=(16, 16))

    # Plot the confusion matrix
    ConfusionMatrixDisplay.from_predictions(
        y_val_integer, y_predicted_integer,
        cmap="Blues",
        display_labels=CLASS_NAMES,
        xticks_rotation="vertical"
    )

    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()  # Show the plot
else:
    print("The number of unique class labels does not match the expected number.")

# %%
print("Unique classes in y_val_rf:", np.unique(y_val_rf))

# If y_val_rf is already integer-encoded:
print("Counts for each class in y_val_rf:", np.bincount(y_val_rf))

# If y_val_rf is not integer-encoded and is categorical or one-hot encoded:
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_val_integer_encoded = le.fit_transform(y_val_rf)  # This assumes y_val_rf is a flat list of class labels
print("Unique classes after encoding:", np.unique(y_val_integer_encoded))
print("Counts for each class after encoding:", np.bincount(y_val_integer_encoded))
# Out:
# Unique classes in y_val_rf: [0 1 2 3]
# Counts for each class in y_val_rf: [30 30 30 30]
# Unique classes after encoding: [0 1 2 3]
# Counts for each class after encoding: [30 30 30 30]

# %%
N_SAMPLES = 4
sample_indices = np.random.randint(x_val.shape[0], size=N_SAMPLES)

images = x_val[sample_indices]

labels = y_val_integer[sample_indices]
classes = [CLASS_NAMES[_] for _ in labels]
fig, axs = plt.subplots(nrows=1, ncols=N_SAMPLES, figsize=(16, 3.5))
plt.suptitle("Groundtruth")
for image_idx, (image, label) in enumerate(zip(images, classes)):
    axs[image_idx].imshow(image)
    axs[image_idx].set_title(label)
    axs[image_idx].axis("off")
plt.tight_layout()
plt.show()


labels = y_predicted_integer[sample_indices]
classes = [CLASS_NAMES[0:3] for _ in labels]
fig, axs = plt.subplots(nrows=1, ncols=N_SAMPLES, figsize=(16, 3.5))
plt.suptitle("InceptionV3 predictions")
for image_idx, (image, label) in enumerate(zip(images, classes)):
    axs[image_idx].imshow(image)
    axs[image_idx].set_title(label)
    axs[image_idx].axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Question 7:</h3>
# <br>
# By running the previous cell several times, see more classification examples. Pay attention to the cases where the network gives wrong predictions. What do you think could be a reason for it?

# %% [markdown]
# ### References
#
# [1] Yi Yang and Shawn Newsam, "Bag-Of-Visual-Words and Spatial Extensions for Land-Use Classification," ACM SIGSPATIAL International Conference on Advances in Geographic Information Systems (ACM GIS), 2010.
#
# [2] Ojala, T., Pietikäinen, M. and Mäenpää, T. (2002), Multiresolution Gray-scale and Rotation Invariant Texture Classification with Local Binary Patterns. IEEE Trans. Pattern Analysis and Machine Intelligence 24(7): 971-987.
#
# [3] Simonyan, K. & Zisserman, A. (2014), 'Very Deep Convolutional Networks for Large-Scale Image Recognition', CoRR abs/1409.1556.
#
# [4] C. Szegedy, V. Vanhoucke, S. Ioffe, J. Shlens and Z. Wojna, "Rethinking the Inception Architecture for Computer Vision," 2016 IEEE Conference on Computer Vision and Pattern Recognition (CVPR), Las Vegas, NV, 2016, pp. 2818-2826.
#
# [5] Kingma, D. P. & Ba, J. (2014), 'Adam: A Method for Stochastic Optimization.', CoRR abs/1412.6980 .
